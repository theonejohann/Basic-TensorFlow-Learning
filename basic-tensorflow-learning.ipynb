# %% [markdown]
# # __Tensorflow Learning with MNIST Dataset__

# %% [markdown]
# Basics of Nueral Networks

# %% [markdown]
# <img src="https://developer.ibm.com/developer/default/articles/cc-models-machine-learning/images/figure03.png"
#      alt="Machine Learning Image"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# ## 0. _Setup_

# %%
# Import Tensorflow
import tensorflow as tf
# Model
from keras.models import Sequential

# Model Visualization
from keras.utils.vis_utils import plot_model

# Visualtization
import matplotlib.pyplot as plt

# %% [markdown]
# The MNIST database of handwritten digits, available from this page, has a training set of 60,000 examples, and a test set of 10,000 examples. It is a subset of a larger set available from NIST. The digits have been size-normalized and centered in a fixed-size image. It is a good database for people who want to try learning techniques and pattern recognition methods on real-world data while spending minimal efforts on preprocessing and formatting.

# %%
# Load Dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(x_train[0])

# %% [markdown]
# ## Model

# %%
# Buliding the Model
model = Sequential()

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer="adam", 
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
# Training the Model
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 1.6466 - accuracy: 0.8786
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2863 - accuracy: 0.9321
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1931 - accuracy: 0.9474
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1630 - accuracy: 0.9541
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1487 - accuracy: 0.9582

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss, val_acc)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1650 - accuracy: 0.9557
# 0.1649724394083023 0.9556999802589417

# %%
model.save("MNIST_Model.h5")
